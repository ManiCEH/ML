# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
# !gdown 15tIjPrstV2RnOMv2VSIKW7yW_M3KjyNa
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15tIjPrstV2RnOMv2VSIKW7yW_M3KjyNa
# To: e:\ML_Algorithm\cars24-car-price.csv
#
#   0%|          | 0.00/1.79M [00:00<?, ?B/s]
#  29%|██▉       | 524k/1.79M [00:00<00:00, 2.19MB/s]
# 100%|██████████| 1.79M/1.79M [00:00<00:00, 5.40MB/s]

# %%
df  = pd.read_csv('cars24-car-price.csv')

# %%
df.head(1)
# Out:
#          full_name  selling_price    year seller_type  km_driven fuel_type  \
# 0  Maruti Alto Std            1.2  2012.0  Individual     120000    Petrol
#
#   transmission_type  mileage  engine  max_power  seats
# 0            Manual     19.7   796.0       46.3    5.0

# %%
df.shape
# Out:
# (19980, 11)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                             full_name  selling_price    year  \
# 0                                     Maruti Alto Std           1.20  2012.0
# 1                              Hyundai Grand i10 Asta           5.50  2016.0
# 2                                    Hyundai i20 Asta           2.15  2010.0
# 3                       Maruti Alto K10 2010-2014 VXI           2.26  2012.0
# 4      Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV           5.70  2015.0
# ...                                               ...            ...     ...
# 19975                   Toyota Platinum Etios 1.4 GXD           6.50  2017.0
# 19976                          Maruti Ertiga BSIV VXI           9.25  2019.0
# 19977                    Skoda Rapid 1.5 TDI Elegance           4.25  2015.0
# 19978                          Mahindra XUV500 W6 2WD          12.25  2016.0
# 19979                        Honda City i-VTEC CVT VX          12.00  2019.0
#
#       seller_type  km_driven fuel_type transmission_type  mileage  engine  \
# 0      Individual     120000    Petrol            Manual    19.70   796.0
# 1      Individual      20000    Petrol            Manual    18.90  1197.0
# 2      Individual      60000    Petrol            Manual    17.00  1197.0
# 3      Individual      37000    Petrol            Manual    20.92   998.0
# 4          Dealer      30000    Diesel            Manual    22.77  1498.0
# ...           ...        ...       ...               ...      ...     ...
# 19975      Dealer      69480    Diesel            Manual    23.59  1364.0
# 19976      Dealer      18000    Petrol            Manual    17.50  1373.0
# 19977      Dealer      67000    Diesel            Manual    21.14  1498.0
# 19978      Dealer    3800000    Diesel            Manual    16.00  2179.0
# 19979      Dealer      13000    Petrol         Automatic    18.00  1497.0
#
#        max_power  seats
# 0          46.30    5.0
# 1          82.00    5.0
# 2          80.00    5.0
# 3          67.10    5.0
# 4          98.59    5.0
# ...          ...    ...
# 19975      67.05    5.0
# 19976      91.10    7.0
# 19977     103.52    5.0
# 19978     140.00    7.0
# 19979     117.60    5.0
#
# [19980 rows x 11 columns]>

# %%
df.describe()
# Out:
#        selling_price          year     km_driven       mileage        engine  \
# count   19980.000000  19980.000000  1.998000e+04  19980.000000  19980.000000
# mean        7.392066   2014.525125  5.824488e+04     19.347219   1476.327401
# std         9.103088      3.249185  5.172509e+04      4.620053    520.449398
# min         0.250000   1991.000000  1.000000e+02      0.000000      0.000000
# 25%         3.400000   2013.000000  3.116425e+04     16.800000   1197.000000
# 50%         5.200000   2015.000000  5.200000e+04     19.160000   1248.000000
# 75%         7.850000   2017.000000  7.400000e+04     22.320000   1582.000000
# max       395.000000   2021.000000  3.800000e+06    120.000000   6752.000000
#
#           max_power         seats
# count  19980.000000  19980.000000
# mean      97.854443      5.317868
# std       45.080670      0.835370
# min        5.000000      2.000000
# 25%       73.900000      5.000000
# 50%       86.700000      5.000000
# 75%      112.000000      5.000000
# max      626.000000     14.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19980 entries, 0 to 19979
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          19980 non-null  object
#  1   selling_price      19980 non-null  float64
#  2   year               19980 non-null  float64
#  3   seller_type        19980 non-null  object
#  4   km_driven          19980 non-null  int64
#  5   fuel_type          19980 non-null  object
#  6   transmission_type  19980 non-null  object
#  7   mileage            19980 non-null  float64
#  8   engine             19980 non-null  float64
#  9   max_power          19980 non-null  float64
#  10  seats              19980 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.7+ MB

# %%
display(df.describe())
# Out:
#        selling_price          year     km_driven       mileage        engine  \
# count   19980.000000  19980.000000  1.998000e+04  19980.000000  19980.000000
# mean        7.392066   2014.525125  5.824488e+04     19.347219   1476.327401
# std         9.103088      3.249185  5.172509e+04      4.620053    520.449398
# min         0.250000   1991.000000  1.000000e+02      0.000000      0.000000
# 25%         3.400000   2013.000000  3.116425e+04     16.800000   1197.000000
# 50%         5.200000   2015.000000  5.200000e+04     19.160000   1248.000000
# 75%         7.850000   2017.000000  7.400000e+04     22.320000   1582.000000
# max       395.000000   2021.000000  3.800000e+06    120.000000   6752.000000
#
#           max_power         seats
# count  19980.000000  19980.000000
# mean      97.854443      5.317868
# std       45.080670      0.835370
# min        5.000000      2.000000
# 25%       73.900000      5.000000
# 50%       86.700000      5.000000
# 75%      112.000000      5.000000
# max      626.000000     14.000000

# %%
df['selling_price'].hist(bins=100)
# Out:
# <Axes: >

# %%
df.head(10)
# Out:
#                                         full_name  selling_price    year  \
# 0                                 Maruti Alto Std           1.20  2012.0
# 1                          Hyundai Grand i10 Asta           5.50  2016.0
# 2                                Hyundai i20 Asta           2.15  2010.0
# 3                   Maruti Alto K10 2010-2014 VXI           2.26  2012.0
# 4  Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV           5.70  2015.0
# 5                        Maruti Wagon R VXI BS IV           3.50  2013.0
# 6                          Hyundai i10 Sportz 1.2           3.15  2013.0
# 7                              Maruti Wagon R VXI           4.10  2018.0
# 8            Hyundai Venue SX Plus Turbo DCT BSIV          10.50  2019.0
# 9                             Mahindra TUV 300 T6           5.75  2017.0
#
#   seller_type  km_driven fuel_type transmission_type  mileage  engine  \
# 0  Individual     120000    Petrol            Manual    19.70   796.0
# 1  Individual      20000    Petrol            Manual    18.90  1197.0
# 2  Individual      60000    Petrol            Manual    17.00  1197.0
# 3  Individual      37000    Petrol            Manual    20.92   998.0
# 4      Dealer      30000    Diesel            Manual    22.77  1498.0
# 5  Individual      35000    Petrol            Manual    18.90   998.0
# 6      Dealer      40000    Petrol            Manual    20.36  1197.0
# 7      Dealer      17512    Petrol            Manual    20.51   998.0
# 8  Individual      20000    Petrol         Automatic    18.15   998.0
# 9      Dealer      70000    Diesel            Manual    18.49  1493.0
#
#    max_power  seats
# 0      46.30    5.0
# 1      82.00    5.0
# 2      80.00    5.0
# 3      67.10    5.0
# 4      98.59    5.0
# 5      67.10    5.0
# 6      78.90    5.0
# 7      67.04    5.0
# 8     118.35    5.0
# 9     100.00    7.0

# %%
df[df['selling_price'] >100].shape[0] / df.shape[0] * 100
# Out:
# 0.055055055055055056

# %%
(df.loc[df.selling_price>100].shape[0] / df.shape[0]) * 100
# Out:
# 0.055055055055055056

# %%
df.loc[df.selling_price > 100, 'selling_price'] = 100

# %%
df['mileage'].hist(bins=50)
# Out:
# <Axes: >

# %%
df['mileage'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df[df['mileage'] <=5].mileage.describe()
# Out:
# count    161.000000
# mean       0.024845
# std        0.315244
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        4.000000
# Name: mileage, dtype: float64

# %%
df.loc[df.mileage==0].shape
# Out:
# (160, 11)

# %%
df[df['mileage']==0.0].shape
# Out:
# (160, 11)

# %%
df.loc[df.mileage==0].shape
# Out:
# (160, 11)

# %%
df[df['mileage'] > 40].fuel_type.value_counts()
# Out:
# fuel_type
# Electric    4
# Name: count, dtype: int64

# %%
df['mileage'].unique
# Out:
# <bound method Series.unique of 0        19.70
# 1        18.90
# 2        17.00
# 3        20.92
# 4        22.77
#          ...
# 19975    23.59
# 19976    17.50
# 19977    21.14
# 19978    16.00
# 19979    18.00
# Name: mileage, Length: 19980, dtype: float64>

# %%
df[df['mileage'] > 40].fuel_type.value_counts()
# Out:
# fuel_type
# Electric    4
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
ax = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 3
#       1 import matplotlib.pyplot as plt
#       2 plt.figure(figsize=(10,8))
# ----> 3 ax = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
#
# File c:\Users\Manikandan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Manikandan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# -> 1892 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1893 if result.dtype is not dtype:
#    1894     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\Manikandan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File c:\Users\Manikandan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Maruti Alto Std'

# %%
df.head(5)
# Out:
#                                         full_name  selling_price    year  \
# 0                                 Maruti Alto Std           1.20  2012.0
# 1                          Hyundai Grand i10 Asta           5.50  2016.0
# 2                                Hyundai i20 Asta           2.15  2010.0
# 3                   Maruti Alto K10 2010-2014 VXI           2.26  2012.0
# 4  Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV           5.70  2015.0
#
#   seller_type  km_driven fuel_type transmission_type  mileage  engine  \
# 0  Individual     120000    Petrol            Manual    19.70   796.0
# 1  Individual      20000    Petrol            Manual    18.90  1197.0
# 2  Individual      60000    Petrol            Manual    17.00  1197.0
# 3  Individual      37000    Petrol            Manual    20.92   998.0
# 4      Dealer      30000    Diesel            Manual    22.77  1498.0
#
#    max_power  seats
# 0      46.30    5.0
# 1      82.00    5.0
# 2      80.00    5.0
# 3      67.10    5.0
# 4      98.59    5.0

# %%
numerical_operation = df.select_dtypes(include='number')
ax = sns.heatmap(numerical_operation.corr(), cmap='YlGnBu',annot=True)

# %%
sns.pairplot(df,y_vars='selling_price')
# Out:
# C:\Users\Manikandan\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['seats'].value_counts()
# Out:
# seats
# 5.0     16681
# 7.0      2370
# 8.0       440
# 4.0       225
# 6.0       143
# 9.0        72
# 10.0       26
# 2.0        21
# 14.0        2
# Name: count, dtype: int64

# %%
df['seats'].value_counts()
# Out:
# seats
# 5.0     16681
# 7.0      2370
# 8.0       440
# 4.0       225
# 6.0       143
# 9.0        72
# 10.0       26
# 2.0        21
# 14.0        2
# Name: count, dtype: int64

# %%
df['seats'].value_counts(normalize=True)
# Out:
# seats
# 5.0     0.834885
# 7.0     0.118619
# 8.0     0.022022
# 4.0     0.011261
# 6.0     0.007157
# 9.0     0.003604
# 10.0    0.001301
# 2.0     0.001051
# 14.0    0.000100
# Name: proportion, dtype: float64

# %%
df.head(5)
# Out:
#                                         full_name  selling_price    year  \
# 0                                 Maruti Alto Std           1.20  2012.0
# 1                          Hyundai Grand i10 Asta           5.50  2016.0
# 2                                Hyundai i20 Asta           2.15  2010.0
# 3                   Maruti Alto K10 2010-2014 VXI           2.26  2012.0
# 4  Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV           5.70  2015.0
#
#   seller_type  km_driven fuel_type transmission_type  mileage  engine  \
# 0  Individual     120000    Petrol            Manual    19.70   796.0
# 1  Individual      20000    Petrol            Manual    18.90  1197.0
# 2  Individual      60000    Petrol            Manual    17.00  1197.0
# 3  Individual      37000    Petrol            Manual    20.92   998.0
# 4      Dealer      30000    Diesel            Manual    22.77  1498.0
#
#    max_power  seats
# 0      46.30    5.0
# 1      82.00    5.0
# 2      80.00    5.0
# 3      67.10    5.0
# 4      98.59    5.0

# %%
df['make'] = df.full_name.apply(lambda x: x.split()[0])
df['model'] = df.full_name.apply(lambda x: x.split()[1:])
df = df.drop('full_name',axis=1)
df.head(1)
# Out:
#    selling_price    year seller_type  km_driven fuel_type transmission_type  \
# 0            1.2  2012.0  Individual     120000    Petrol            Manual
#
#    mileage  engine  max_power  seats    make        model
# 0     19.7   796.0       46.3    5.0  Maruti  [Alto, Std]

# %%
display(df.describe(include=object))
# Out:
#        seller_type fuel_type transmission_type    make                model
# count        19980     19980             19980   19980                19980
# unique           3         5                 2      42                 3321
# top         Dealer    Diesel            Manual  Maruti  [Swift, Dzire, VDI]
# freq         11973      9817             16029    5650                  210

# %%
df.loc[df.selling_price <= df.selling_price.quantile(0.9)].groupby('seller_type')['selling_price'].plot.density()
plt.legend()

# %%
for col in ['seller_type','fuel_type','seats']:
    plt.figure(figsize=(10,5))
    sns.boxplot(y='selling_price',x=col,data=df)
    plt.title('col vs selling_price')
    plt.show()

# %%
df['log_selling_price'] = np.log(df['selling_price'].values)
df['log_selling_price']
# Out:
# 0        0.182322
# 1        1.704748
# 2        0.765468
# 3        0.815365
# 4        1.740466
#            ...
# 19975    1.871802
# 19976    2.224624
# 19977    1.446919
# 19978    2.505526
# 19979    2.484907
# Name: log_selling_price, Length: 19980, dtype: float64

# %%
df['make'].value_counts()
# Out:
# make
# Maruti           5650
# Hyundai          3646
# Honda            1781
# Mahindra         1291
# Toyota           1205
# Tata              975
# Ford              908
# Volkswagen        762
# Renault           636
# Mercedes-Benz     501
# BMW               483
# Skoda             422
# Chevrolet         406
# Audi              324
# Nissan            290
# Datsun            170
# Fiat              114
# Jaguar             80
# Land               56
# Jeep               45
# Volvo              43
# Mitsubishi         39
# Kia                33
# Porsche            26
# Mini               23
# MG                 20
# Isuzu              10
# Lexus              10
# Force               5
# Bentley             4
# Ambassador          4
# OpelCorsa           3
# ISUZU               2
# DC                  2
# Maserati            2
# Daewoo              2
# Premier             2
# Lamborghini         1
# Ferrari             1
# Mercedes-AMG        1
# Rolls-Royce         1
# Opel                1
# Name: count, dtype: int64

# %%
############## Feaure Engineering ###################################

# %%
from datetime import datetime
current_year = datetime.now().year
age = current_year - df['year']
plt.scatter(age, df.selling_price)

# %%
df.head(2)
# Out:
#    selling_price    year seller_type  km_driven fuel_type transmission_type  \
# 0            1.2  2012.0  Individual     120000    Petrol            Manual
# 1            5.5  2016.0  Individual      20000    Petrol            Manual
#
#    mileage  engine  max_power  seats     make               model  \
# 0     19.7   796.0       46.3    5.0   Maruti         [Alto, Std]
# 1     18.9  1197.0       82.0    5.0  Hyundai  [Grand, i10, Asta]
#
#    log_sellig_price  log_selling_price
# 0          0.182322           0.182322
# 1          1.704748           1.704748

# %%
transmission_dummy = pd.get_dummies(df['transmission_type'])
transmission_dummy
# Out:
#        Automatic  Manual
# 0          False    True
# 1          False    True
# 2          False    True
# 3          False    True
# 4          False    True
# ...          ...     ...
# 19975      False    True
# 19976      False    True
# 19977      False    True
# 19978      False    True
# 19979       True   False
#
# [19980 rows x 2 columns]

# %%
df = pd.concat([df,transmission_dummy],axis=1)
df = df.drop(["transmission_type", "Automatic"], axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[155], line 2
#       1 df = pd.concat([df,transmission_dummy],axis=1)
# ----> 2 df = df.drop(["transmission_type", "Automatic"], axis=1)
#       3 df
#
# File c:\Users\Manikandan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File c:\Users\Manikandan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Users\Manikandan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4782, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4780     labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    4781     if errors == "raise" and labels_missing:
# -> 4782         raise KeyError(f"{labels} not found in axis")
#    4784 if isinstance(mask.dtype, ExtensionDtype):
#    4785     # GH#45860
#    4786     mask = mask.to_numpy(dtype=bool)
#
# KeyError: "['transmission_type' 'Automatic'] not found in axis"

# %%
df
# Out:
#        selling_price    year seller_type  km_driven fuel_type  mileage  \
# 0               1.20  2012.0  Individual     120000    Petrol    19.70
# 1               5.50  2016.0  Individual      20000    Petrol    18.90
# 2               2.15  2010.0  Individual      60000    Petrol    17.00
# 3               2.26  2012.0  Individual      37000    Petrol    20.92
# 4               5.70  2015.0      Dealer      30000    Diesel    22.77
# ...              ...     ...         ...        ...       ...      ...
# 19975           6.50  2017.0      Dealer      69480    Diesel    23.59
# 19976           9.25  2019.0      Dealer      18000    Petrol    17.50
# 19977           4.25  2015.0      Dealer      67000    Diesel    21.14
# 19978          12.25  2016.0      Dealer    3800000    Diesel    16.00
# 19979          12.00  2019.0      Dealer      13000    Petrol    18.00
#
#        engine  max_power  seats      make  \
# 0       796.0      46.30    5.0    Maruti
# 1      1197.0      82.00    5.0   Hyundai
# 2      1197.0      80.00    5.0   Hyundai
# 3       998.0      67.10    5.0    Maruti
# 4      1498.0      98.59    5.0      Ford
# ...       ...        ...    ...       ...
# 19975  1364.0      67.05    5.0    Toyota
# 19976  1373.0      91.10    7.0    Maruti
# 19977  1498.0     103.52    5.0     Skoda
# 19978  2179.0     140.00    7.0  Mahindra
# 19979  1497.0     117.60    5.0     Honda
#
#                                                   model  log_sellig_price  \
# 0                                           [Alto, Std]          0.182322
# 1                                    [Grand, i10, Asta]          1.704748
# 2                                           [i20, Asta]          0.765468
# 3                           [Alto, K10, 2010-2014, VXI]          0.815365
# 4      [Ecosport, 2015-2021, 1.5, TDCi, Titanium, BSIV]          1.740466
# ...                                                 ...               ...
# 19975                       [Platinum, Etios, 1.4, GXD]          1.871802
# 19976                               [Ertiga, BSIV, VXI]          2.224624
# 19977                       [Rapid, 1.5, TDI, Elegance]          1.446919
# 19978                                 [XUV500, W6, 2WD]          2.505526
# 19979                           [City, i-VTEC, CVT, VX]          2.484907
#
#        log_selling_price  Manual  Manual  Manual  Manual  Automatic  Manual
# 0               0.182322    True    True    True    True      False    True
# 1               1.704748    True    True    True    True      False    True
# 2               0.765468    True    True    True    True      False    True
# 3               0.815365    True    True    True    True      False    True
# 4               1.740466    True    True    True    True      False    True
# ...                  ...     ...     ...     ...     ...        ...     ...
# 19975           1.871802    True    True    True    True      False    True
# 19976           2.224624    True    True    True    True      False    True
# 19977           1.446919    True    True    True    True      False    True
# 19978           2.505526    True    True    True    True      False    True
# 19979           2.484907   False   False   False   False       True   False
#
# [19980 rows x 19 columns]
